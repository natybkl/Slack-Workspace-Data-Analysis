# %% [markdown]
# # Inserting all users, messages and channels into a MongoDB database

# %%
import os
import sys
import pprint
import uuid
import json
import pandas as pd
import os, sys

# Add parent directory to path to import modules from src
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)


from pymongo import MongoClient
from src.loader import SlackDataLoader


slack_data_path = os.path.abspath('../anonymized')

# %%
class DBWithSchema:
    def __init__(self) -> None:
        self.client = MongoClient("mongodb://localhost:27017/")
        self.db = self.client["SlackDb"]

        self.user_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["user_id", "real_name"],
                "properties": {
                    "user_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "real_name": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    }
                }
            }
        }

        self.channel_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["channel_id", "name"],
                "properties": {
                    "channel_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "name": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    }
                }
            }
        }

        self.message_validator = {
            "$jsonSchema": {
                "bsonType": "object",
                "required": ["ts", "msg_id", "text", "user_id", "channel_id", "mentions", "reactions", "replies"],
                "properties": {
                    "ts": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },

                    "msg_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "text": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "user_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "channel_id": {
                        "bsonType": "string",
                        "description": "must be a string and is required"
                    },
                    "mentions": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "string"
                        },
                        "description": "must be an array of strings"
                    },
                    "reactions": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "object",
                            "required": ["name", "users", "count"],
                            "properties": {
                                "name": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                },
                                "users": {
                                    "bsonType": "array",
                                    "items": {
                                        "bsonType": "string"
                                    },
                                    "description": "must be an array of strings"
                                },
                                "count": {
                                    "bsonType": "number",
                                    "description": "must be a number and is required"
                                }
                            }
                        }
                    },
                    "replies": {
                        'bsonType': ['array', 'null'],

                        "items": {
                            "bsonType": "object",
                            "required": ["user", "ts"],
                            "properties": {
                                "user": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                },
                                "ts": {
                                    "bsonType": "string",
                                    "description": "must be a string and is required"
                                }
                            }
                        }
                    }
                }
            }
        }


        try:
            self.db.create_collection("users")
            self.db.create_collection("channels")
            self.db.create_collection("messages")
        except Exception as e:
            print("error: ", e)

        self.db.command("collMod", "users", validator=self.user_validator)
        self.db.command("collMod", "channels", validator=self.channel_validator)
        self.db.command("collMod", "messages", validator=self.message_validator)



    def list_collections(self):
        return self.db.list_collection_names()
    
    def get_validation(self, collection_name: str) -> dict:
        self.check_if_collection_exist(collection_name)
        return self.db.get_collection(collection_name).options()
    
    def check_if_collection_exist(self, collection_name: str):
        if not self.list_collections().__contains__(collection_name):
            raise Exception(f"Collection, {collection_name} not found.")

    def insert_to_collection(self, collection_name, data):
        self.check_if_collection_exist(collection_name)
        collection = self.db[collection_name]
        return collection.insert_one(data)

    def insert_many_to_collection(self, collection_name, data):
        self.check_if_collection_exist(collection_name)
        result = self.db[collection_name].insert_many(data)
        return result.inserted_ids



    def find_all(self, collection_name):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find()

    def find(self, collection_name, key, value):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find({key: value})
    
    def find_by_id(self, collection_name, _id):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find

    def find_one(self, collection_name, key, value):
        self.check_if_collection_exist(collection_name)
        return self.db[collection_name].find_one({key: value})

# %%
database = DBWithSchema()
# Out:
# error:  collection users already exists

# %% [markdown]
# # Adding all users from the slack workspace to the database

# %%
users = SlackDataLoader(slack_data_path).users

formatted_users = [{"user_id": user["id"], "real_name": user["real_name"]} for user in users]

database.insert_many_to_collection('users', formatted_users)
# Out:
# [ObjectId('6569a9b914c3b0d37a8165ec'),
#  ObjectId('6569a9b914c3b0d37a8165ed'),
#  ObjectId('6569a9b914c3b0d37a8165ee'),
#  ObjectId('6569a9b914c3b0d37a8165ef'),
#  ObjectId('6569a9b914c3b0d37a8165f0'),
#  ObjectId('6569a9b914c3b0d37a8165f1'),
#  ObjectId('6569a9b914c3b0d37a8165f2'),
#  ObjectId('6569a9b914c3b0d37a8165f3'),
#  ObjectId('6569a9b914c3b0d37a8165f4'),
#  ObjectId('6569a9b914c3b0d37a8165f5'),
#  ObjectId('6569a9b914c3b0d37a8165f6'),
#  ObjectId('6569a9b914c3b0d37a8165f7'),
#  ObjectId('6569a9b914c3b0d37a8165f8'),
#  ObjectId('6569a9b914c3b0d37a8165f9'),
#  ObjectId('6569a9b914c3b0d37a8165fa'),
#  ObjectId('6569a9b914c3b0d37a8165fb'),
#  ObjectId('6569a9b914c3b0d37a8165fc'),
#  ObjectId('6569a9b914c3b0d37a8165fd'),
#  ObjectId('6569a9b914c3b0d37a8165fe'),
#  ObjectId('6569a9b914c3b0d37a8165ff'),
#  ObjectId('6569a9b914c3b0d37a816600'),
#  ObjectId('6569a9b914c3b0d37a816601'),
#  ObjectId('6569a9b914c3b0d37a816602'),
#  ObjectId('6569a9b914c3b0d37a816603'),
#  ObjectId('6569a9b914c3b0d37a816604'),
#  ObjectId('6569a9b914c3b0d37a816605'),
#  ObjectId('6569a9b914c3b0d37a816606'),
#  ObjectId('6569a9b914c3b0d37a816607'),
#  ObjectId('6569a9b914c3b0d37a816608'),
#  ObjectId('6569a9b914c3b0d37a816609'),
#  ObjectId('6569a9b914c3b0d37a81660a'),
#  ObjectId('6569a9b914c3b0d37a81660b'),
#  ObjectId('6569a9b914c3b0d37a81660c'),
#  ObjectId('6569a9b914c3b0d37a81660d'),
#  ObjectId('6569a9b914c3b0d37a81660e'),
#  ObjectId('6569a9b914c3b0d37a81660f'),
#  ObjectId('6569a9b914c3b0d37a816610'),
#  ObjectId('6569a9b914c3b0d37a816611'),
#  ObjectId('6569a9b914c3b0d37a816612'),
#  ObjectId('6569a9b914c3b0d37a816613'),
#  ObjectId('6569a9b914c3b0d37a816614'),
#  ObjectId('6569a9b914c3b0d37a816615'),
#  ObjectId('6569a9b914c3b0d37a816616'),
#  ObjectId('6569a9b914c3b0d37a816617'),
#  ObjectId('6569a9b914c3b0d37a816618'),
#  ObjectId('6569a9b914c3b0d37a816619'),
#  ObjectId('6569a9b914c3b0d37a81661a'),
#  ObjectId('6569a9b914c3b0d37a81661b'),
#  ObjectId('6569a9b914c3b0d37a81661c'),
#  ObjectId('6569a9b914c3b0d37a81661d'),
#  ObjectId('6569a9b914c3b0d37a81661e'),
#  ObjectId('6569a9b914c3b0d37a81661f'),
#  ObjectId('6569a9b914c3b0d37a816620'),
#  ObjectId('6569a9b914c3b0d37a816621'),
#  ObjectId('6569a9b914c3b0d37a816622'),
#  ObjectId('6569a9b914c3b0d37a816623'),
#  ObjectId('6569a9b914c3b0d37a816624'),
#  ObjectId('6569a9b914c3b0d37a816625'),
#  ObjectId('6569a9b914c3b0d37a816626'),
#  ObjectId('6569a9b914c3b0d37a816627'),
#  ObjectId('6569a9b914c3b0d37a816628'),
#  ObjectId('6569a9b914c3b0d37a816629'),
#  ObjectId('6569a9b914c3b0d37a81662a'),
#  ObjectId('6569a9b914c3b0d37a81662b'),
#  ObjectId('6569a9b914c3b0d37a81662c'),
#  ObjectId('6569a9b914c3b0d37a81662d'),
#  ObjectId('6569a9b914c3b0d37a81662e'),
#  ObjectId('6569a9b914c3b0d37a81662f'),
#  ObjectId('6569a9b914c3b0d37a816630'),
#  ObjectId('6569a9b914c3b0d37a816631'),
#  ObjectId('6569a9b914c3b0d37a816632')]

# %%
#first five user recorded in the database 
records = database.find_all('users')
for record in records[:5]:
    pprint.pprint(record)
# Out:
# {'_id': ObjectId('6569a9b914c3b0d37a8165ec'),
#  'real_name': 'Rachel Mann',
#  'user_id': 'U03T89ACUUW'}
# {'_id': ObjectId('6569a9b914c3b0d37a8165ed'),
#  'real_name': 'Bridget Glover',
#  'user_id': 'U03TEPYRM2P'}
# {'_id': ObjectId('6569a9b914c3b0d37a8165ee'),
#  'real_name': 'Victor Mayo',
#  'user_id': 'U03TNP8Q8CT'}
# {'_id': ObjectId('6569a9b914c3b0d37a8165ef'),
#  'real_name': 'Brian Flores',
#  'user_id': 'U03TT5KEYCF'}
# {'_id': ObjectId('6569a9b914c3b0d37a8165f0'),
#  'real_name': 'Joanne Thomas',
#  'user_id': 'U03TX2VN6H5'}

# %% [markdown]
# # Adding all channels of the slack workspace to the database

# %%
all_channels = SlackDataLoader(slack_data_path).channels

formatted_channels = [{"channel_id": channel["id"], "name": channel["name"]} for channel in all_channels]

database.insert_many_to_collection('channels', formatted_channels)
# Out:
# [ObjectId('6569ab7414c3b0d37a816633'),
#  ObjectId('6569ab7414c3b0d37a816634'),
#  ObjectId('6569ab7414c3b0d37a816635'),
#  ObjectId('6569ab7414c3b0d37a816636'),
#  ObjectId('6569ab7414c3b0d37a816637'),
#  ObjectId('6569ab7414c3b0d37a816638'),
#  ObjectId('6569ab7414c3b0d37a816639'),
#  ObjectId('6569ab7414c3b0d37a81663a'),
#  ObjectId('6569ab7414c3b0d37a81663b'),
#  ObjectId('6569ab7414c3b0d37a81663c'),
#  ObjectId('6569ab7414c3b0d37a81663d'),
#  ObjectId('6569ab7414c3b0d37a81663e'),
#  ObjectId('6569ab7414c3b0d37a81663f'),
#  ObjectId('6569ab7414c3b0d37a816640'),
#  ObjectId('6569ab7414c3b0d37a816641'),
#  ObjectId('6569ab7414c3b0d37a816642'),
#  ObjectId('6569ab7414c3b0d37a816643'),
#  ObjectId('6569ab7414c3b0d37a816644'),
#  ObjectId('6569ab7414c3b0d37a816645'),
#  ObjectId('6569ab7414c3b0d37a816646'),
#  ObjectId('6569ab7414c3b0d37a816647'),
#  ObjectId('6569ab7414c3b0d37a816648'),
#  ObjectId('6569ab7414c3b0d37a816649'),
#  ObjectId('6569ab7414c3b0d37a81664a'),
#  ObjectId('6569ab7414c3b0d37a81664b'),
#  ObjectId('6569ab7414c3b0d37a81664c'),
#  ObjectId('6569ab7414c3b0d37a81664d'),
#  ObjectId('6569ab7414c3b0d37a81664e'),
#  ObjectId('6569ab7414c3b0d37a81664f'),
#  ObjectId('6569ab7414c3b0d37a816650'),
#  ObjectId('6569ab7414c3b0d37a816651'),
#  ObjectId('6569ab7414c3b0d37a816652'),
#  ObjectId('6569ab7414c3b0d37a816653'),
#  ObjectId('6569ab7414c3b0d37a816654'),
#  ObjectId('6569ab7414c3b0d37a816655'),
#  ObjectId('6569ab7414c3b0d37a816656'),
#  ObjectId('6569ab7414c3b0d37a816657'),
#  ObjectId('6569ab7414c3b0d37a816658'),
#  ObjectId('6569ab7414c3b0d37a816659')]

# %%
#first five channels recorded in the database 
records = database.find_all('channels')
for record in records[:5]:
    pprint.pprint(record)
# Out:
# {'_id': ObjectId('6569ab7414c3b0d37a816633'),
#  'channel_id': 'C03T0APHX63',
#  'name': 'all-community-building'}
# {'_id': ObjectId('6569ab7414c3b0d37a816634'),
#  'channel_id': 'C03T0AX4K6K',
#  'name': 'all-technical-support'}
# {'_id': ObjectId('6569ab7414c3b0d37a816635'),
#  'channel_id': 'C03T89KDGA2',
#  'name': 'all-career-exercises'}
# {'_id': ObjectId('6569ab7414c3b0d37a816636'),
#  'channel_id': 'C03T89PMJKG',
#  'name': 'all-resources'}
# {'_id': ObjectId('6569ab7414c3b0d37a816637'),
#  'channel_id': 'C03TBUCU4UD',
#  'name': 'random'}

# %% [markdown]
# # Adding all messages in the slack workspace to the database

# %%
def remove_duplicates(json_files, key):
    seen = set()
    unique_json_files = []

    for json_file in json_files:
        json_key = json_file.get(key)
        if json_key not in seen:
            unique_json_files.append(json_file)
            seen.add(json_key)

    return unique_json_files

def get_messages_dict(msgs):
    msg_list = {
            "msg_id":[],
            "text":[],
            "user":[],
            "mentions":[],
            "reactions":[],
            "replies":[],
            "replies_to":[],
            "ts":[],
            }


    for msg in msgs:
        if "subtype" not in msg:
            try:
                msg_list["msg_id"].append(msg["client_msg_id"])
            except:
                msg_list["msg_id"].append(None)
            msg_list["text"].append(msg["text"])

            msg_list["user"].append(msg["user"])
            msg_list["ts"].append(msg["ts"])

            
            if "reactions" in msg:
                msg_list["reactions"].append(msg["reactions"])
            else:

                msg_list["reactions"].append(None)

            if "parent_user_id" in msg:
                msg_list["replies_to"].append(msg["ts"])
            else:
                msg_list["replies_to"].append(None)

            if "thread_ts" in msg and "reply_users" in msg:
                msg_list["replies"].append(msg["replies"])
            else:
                msg_list["replies"].append(None)
            
            if "blocks" in msg and msg["blocks"]:
                mention_list = []
                
                for blk in msg["blocks"]:
                    if "elements" in blk:
                        for elm in blk["elements"]:
                            if "elements" in elm:
                                for elm_ in elm["elements"]:
                                    
                                    if "type" in elm_:
                                      
                                        if elm_["type"] == "user":
                                            mention_list.append(elm_["user_id"])
                                       


                msg_list["mentions"].append(mention_list)
            else:
                msg_list["mentions"].append(None)
    
    return msg_list



def get_messages_from_channel(channel_path):
    json_files = [
        f"{channel_path}/{pos_json}" 
        for pos_json in os.listdir(channel_path) 
        if pos_json.endswith('.json')
    ]    
    combined = []

    for json_file in json_files:
        with open(json_file, 'r', encoding="utf8") as slack_data:
            json_content = json.load(slack_data)
            combined.extend(json_content)
        
    # print(combined[0])
    msg_list = get_messages_dict(combined)
    df = pd.DataFrame(msg_list)
    
    return df

# %%
all_messages = []

# print(SlackDataLoader(slack_data_path).channels[0])
for channel in SlackDataLoader(slack_data_path).channels:

    messages = get_messages_from_channel(f"../anonymized/{channel['name']}")

    formatted_messages = messages.apply(lambda msg: {
        "msg_id": msg["msg_id"] if msg["msg_id"] else str(uuid.uuid4()),
        "text": msg["text"],
        "user_id": msg["user"],
        "mentions": msg["mentions"] if msg["mentions"] else [],
        "reactions": msg["reactions"] if msg["reactions"] else [],
        "replies": msg["replies"] if msg["replies"] else [],
        "ts": msg["ts"],
        "channel_id": channel["id"]
    }, axis=1)

    all_messages.extend(formatted_messages.to_list())


all_messages = remove_duplicates(all_messages, 'msg_id')

database.insert_many_to_collection('messages', all_messages)
# Out:
# {'client_msg_id': 'aaea2ec8-1461-4705-98c0-fda055acf96e', 'type': 'message', 'text': 'morning boss', 'user': 'U03UVHCV6KB', 'ts': '1666940798.397899', 'blocks': [{'type': 'rich_text', 'block_id': '8Nn0E', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'morning boss'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc9619121f99', 'image_72': 'https://secure.gravatar.com/avatar/c9619121f998ee4a7e46177f2a5729de.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-72.png', 'first_name': 'Gregory', 'real_name': 'Gregory Bowman', 'display_name': 'Gregory Bowman', 'team': 'T03U4J8HMUG', 'name': 'Gregory', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': 'bd822d64-f723-4be4-a79e-26d5e69f0d94', 'type': 'message', 'text': "good morning,\ni'm not able to access the tenx platform with my chrome navigator. i'm getting error since last week.", 'user': 'U03UH397319', 'ts': '1661761179.568549', 'blocks': [{'type': 'rich_text', 'block_id': 'Okwr1', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "good morning,\ni'm not able to access the tenx platform with my chrome navigator. i'm getting error since last week."}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Monica', 'real_name': 'Monica Newton', 'display_name': 'Monica Newton', 'team': 'T03U4J8HMUG', 'name': 'Monica', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1661761179.568549', 'reply_count': 3, 'reply_users_count': 3, 'latest_reply': '1661761744.523529', 'reply_users': ['U03TEPYRM2P', 'U03UD68RQH3', 'U03UH397319'], 'replies': [{'user': 'U03TEPYRM2P', 'ts': '1661761228.743599'}, {'user': 'U03UD68RQH3', 'ts': '1661761229.431239'}, {'user': 'U03UH397319', 'ts': '1661761744.523529'}], 'is_locked': False, 'subscribed': True, 'last_read': '1661761744.523529', 'attachments': None}
# {'client_msg_id': '3160c0ab-f464-47f5-bd4a-1c6c994b7fbc', 'type': 'message', 'text': 'are there any career exercise submissions this week?', 'user': 'U03UUP56MDF', 'ts': '1666978176.519639', 'blocks': [{'type': 'rich_text', 'block_id': 'Bo/D', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'are there any career exercise submissions this week?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'g00725318689', 'image_72': 'https://secure.gravatar.com/avatar/007253186898705d4f28c384188b8a63.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-72.png', 'first_name': 'Margaret', 'real_name': 'Margaret Jackson', 'display_name': 'Margaret Jackson', 'team': 'T03U4J8HMUG', 'name': 'Margaret', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1666978176.519639', 'reply_count': 3, 'reply_users_count': 3, 'latest_reply': '1666978276.169519', 'reply_users': ['U03UD68RQH3', 'U03UUP56MDF', 'U03V61VGQG0'], 'replies': [{'user': 'U03UD68RQH3', 'ts': '1666978194.251119'}, {'user': 'U03UUP56MDF', 'ts': '1666978222.584899'}, {'user': 'U03V61VGQG0', 'ts': '1666978276.169519'}], 'is_locked': False, 'subscribed': False, 'attachments': None}
# {'client_msg_id': '0d97bf05-dce6-4473-9a57-784373db5889', 'type': 'message', 'text': '<https://reactnative.dev/docs/environment-setup>', 'user': 'U03UHB8CXDY', 'ts': '1666946574.721569', 'blocks': [{'type': 'rich_text', 'block_id': 'SZJ', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://reactnative.dev/docs/environment-setup', 'text': None}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '374fee609510', 'image_72': 'https://avatars.slack-edge.com/2022-09-30/4159182498980_374fee609510e6ff1526_72.jpg', 'first_name': 'Alejandra', 'real_name': 'Alejandra Carpenter', 'display_name': 'Alejandra Carpenter', 'team': 'T03U4J8HMUG', 'name': 'Alejandra', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://reactnative.dev/docs/environment-setup', 'image_url': 'https://reactnative.dev/img/logo-og.png', 'image_width': 476, 'image_height': 250, 'image_bytes': 10754, 'service_icon': 'https://reactnative.dev/img/pwa/manifest-icon-512.png', 'id': 1, 'original_url': 'https://reactnative.dev/docs/environment-setup', 'fallback': 'setting up the development environment · react native', 'text': 'this page will help you install and build your first react native app.', 'title': 'setting up the development environment · react native', 'title_link': 'https://reactnative.dev/docs/environment-setup', 'service_name': 'reactnative.dev', 'message_blocks': None}]}
# {'client_msg_id': 'd0cd6430-6a6f-4568-9fff-34be8b877b94', 'type': 'message', 'text': '"i hope that in this month to come, you make mistakes. because if you are making mistakes, then you are making new things, trying new things, learning, living, pushing yourself, changing yourself, changing your world. you\'re doing things you\'ve never done before and more importantly, you\'re doing something." *– neil gaiman*', 'user': 'U03V1AM5TFA', 'ts': '1666942524.174859', 'blocks': [{'type': 'rich_text', 'block_id': 'UvID', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': '"i hope that in this month to come, you make mistakes. because if you are making mistakes, then you are making new things, trying new things, learning, living, pushing yourself, changing yourself, changing your world. you\'re doing things you\'ve never done before and more importantly, you\'re doing something." '}, {'type': 'text', 'text': '– neil gaiman', 'style': {'bold': True}}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '102fdd0c183f', 'image_72': 'https://avatars.slack-edge.com/2022-08-19/3963732043714_102fdd0c183f8d6d4215_72.png', 'first_name': 'Lynn', 'real_name': 'Lynn Shepherd', 'display_name': 'Lynn Shepherd', 'team': 'T03U4J8HMUG', 'name': 'Lynn', 'is_restricted': False, 'is_ultra_restricted': False}, 'reactions': [{'name': 'raised_hands', 'users': ['U03UVHCV6KB', 'U03U1HAG9TR', 'U03UAKATQ22', 'U03UG0SFHGT'], 'count': 4}, {'name': 'raised_hands::skin-tone-4', 'users': ['U03UG4Q7V42'], 'count': 1}], 'attachments': None}
# {'client_msg_id': 'bc642541-55f2-441c-b975-bfa4313fd6af', 'type': 'message', 'text': "didn't they earn 28b us?", 'user': 'U03U93GNNVB', 'ts': '1666956301.312849', 'blocks': [{'type': 'rich_text', 'block_id': 'Yxw=I', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "didn't they earn 28b us?"}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'a49779ad093d', 'image_72': 'https://avatars.slack-edge.com/2022-08-22/3994045204528_a49779ad093d4fc39a87_72.jpg', 'first_name': 'Lawrence', 'real_name': 'Lawrence Braun', 'display_name': 'Lawrence Braun', 'team': 'T03U4J8HMUG', 'name': 'Lawrence', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1666900816.202839', 'parent_user_id': 'U03UHB8CXDY', 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1660833152.776779', 'user': 'U03U9DB7REG', 'text': '<@u03u9db7reg> has joined the channel', 'blocks': None, 'attachments': None}
# {'client_msg_id': '1e26c0f4-b1eb-4c5b-b7c6-c084d457daff', 'type': 'message', 'text': "*daily standup reminder*:timer_clock:\n*<!here>*  *<@u03tepyrm2p>* *<@u03up7v9q57>* *<@u03u4gulu3y>* \n today's *standup*  will start in joannemin! join the meeting with this link below.\n:point_right: <http://meet.Stephanie.com/ysb-kjdn-hpp|meet.Stephanie.com/ysb-kjdn-hpp> (if you want to join now, we are listening to some good music)\n:sparkles:be reminded that today's  hotseat guest is  <@u03uun8m4rx>  so get ready with your questions.", 'user': 'U03V1AM5TFA', 'ts': '1666943400.667839', 'blocks': [{'type': 'rich_text', 'block_id': '+uR', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'daily standup reminder', 'style': {'bold': True}}, {'type': 'emoji', 'name': 'timer_clock', 'unicode': '23f2-fe0f'}, {'type': 'text', 'text': '\n'}, {'type': 'broadcast', 'range': 'here', 'style': {'bold': True}}, {'type': 'text', 'text': '  ', 'style': {'bold': True}}, {'type': 'user', 'user_id': 'U03TEPYRM2P', 'style': {'bold': True}}, {'type': 'text', 'text': ' ', 'style': {'bold': True}}, {'type': 'user', 'user_id': 'U03UP7V9Q57', 'style': {'bold': True}}, {'type': 'text', 'text': ' ', 'style': {'bold': True}}, {'type': 'user', 'user_id': 'U03U4GULU3Y', 'style': {'bold': True}}, {'type': 'text', 'text': ' ', 'style': {'bold': True}}, {'type': 'text', 'text': "\n today's"}, {'type': 'text', 'text': ' standup', 'style': {'bold': True}}, {'type': 'text', 'text': '  will start in Joannemin! join the meeting with this link below.\n'}, {'type': 'emoji', 'name': 'point_right', 'unicode': '1f449'}, {'type': 'text', 'text': ' '}, {'type': 'link', 'url': 'http://meet.Stephanie.com/ysb-kjdn-hpp', 'text': 'meet.Stephanie.com/ysb-kjdn-hpp'}, {'type': 'text', 'text': ' (if you want to join now, we are listening to some good music)\n'}, {'type': 'emoji', 'name': 'sparkles', 'unicode': '2728'}, {'type': 'text', 'text': "be reminded that today's  hotseat guest is  "}, {'type': 'user', 'user_id': 'U03UUN8M4RX'}, {'type': 'text', 'text': '  so get ready with your questions.'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '102fdd0c183f', 'image_72': 'https://avatars.slack-edge.com/2022-08-19/3963732043714_102fdd0c183f8d6d4215_72.png', 'first_name': 'Lynn', 'real_name': 'Lynn Shepherd', 'display_name': 'Lynn Shepherd', 'team': 'T03U4J8HMUG', 'name': 'Lynn', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1661596965.870209', 'user': 'U03UD4FEDHB', 'text': '<@u03ud4fedhb> has joined the channel', 'blocks': None, 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1661768995.430999', 'user': 'U03UJGRN5E0', 'text': '<@u03ujgrn5e0> has joined the channel', 'blocks': None, 'attachments': None}
# {'client_msg_id': '9b3ce56f-5782-48f6-8d9f-feca04504328', 'type': 'message', 'text': "welcome to week 2 everyone. let's keep up the momentum :rocket:", 'user': 'U03TEPYRM2P', 'ts': '1661756798.203129', 'blocks': [{'type': 'rich_text', 'block_id': 'jIt', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "welcome to week 2 everyone. let's keep up the momentum "}, {'type': 'emoji', 'name': 'rocket', 'unicode': '1f680'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'f113df20f89c', 'image_72': 'https://avatars.slack-edge.com/2022-08-23/3977820714178_f113df20f89c894062b4_72.jpg', 'first_name': 'Bridget', 'real_name': 'Bridget Glover', 'display_name': 'Bridget Glover', 'team': 'T03U4J8HMUG', 'name': 'Bridget', 'is_restricted': False, 'is_ultra_restricted': False}, 'reactions': [{'name': 'heart', 'users': ['U03UFV7HFNF', 'U03U1HAG9TR', 'U03UG1RTXAP', 'U03UJN29Y4C', 'U03UD4FEDHB', 'U03UG0YHAUT', 'U03UG569P7U'], 'count': 7}, {'name': 'raised_hands', 'users': ['U03UJGP0C68', 'U03UG0YHAUT', 'U03U9EJR362', 'U03UD68RQH3', 'U03UG4Q7V42'], 'count': 5}, {'name': 'boom', 'users': ['U03V1AM5TFA'], 'count': 1}], 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1661767928.863399', 'user': 'U03UJGP0C68', 'text': '<@u03ujgp0c68> has joined the channel', 'blocks': None, 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1661765937.810099', 'user': 'U03U9FWPNCE', 'text': '<@u03u9fwpnce> has joined the channel', 'blocks': None, 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1661766771.710279', 'user': 'U03UG569P7U', 'text': '<@u03ug569p7u> has joined the channel', 'blocks': None, 'attachments': None}
# {'client_msg_id': 'f7900b3a-1b60-48a2-aa00-0ca9b2f12e44', 'type': 'message', 'text': 'hello <!channel> are you excited for this weeks challenge?\nthe python challenge is going to be focused on graphs.\nresources:\n-<https://medium.com/basecs/from-theory-to-practice-representing-graphs-cfd782c5be38>\n-<https://medium.com/basecs/deep-dive-through-a-graph-dfs-traversal-8177df5d0f13>\n-<https://www.youtube.com/watch?v=j0iycybdzfa>\n\n\ncontest link:<https://www.hackerrank.com/Joanne-academy-batch-6-challenge-Joanne>\n\nhave fun!!!!!!!', 'user': 'U03U9DB7REG', 'ts': '1666935658.425129', 'blocks': [{'type': 'rich_text', 'block_id': 'JRF', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'hello '}, {'type': 'broadcast', 'range': 'channel'}, {'type': 'text', 'text': ' are you excited for this weeks challenge?\nthe python challenge is going to be focused on graphs.\nresources:\n-'}, {'type': 'link', 'url': 'https://medium.com/basecs/from-theory-to-practice-representing-graphs-cfd782c5be38', 'text': None}, {'type': 'text', 'text': '\n-'}, {'type': 'link', 'url': 'https://medium.com/basecs/deep-dive-through-a-graph-dfs-traversal-8177df5d0f13', 'text': None}, {'type': 'text', 'text': '\n-'}, {'type': 'link', 'url': 'https://www.youtube.com/watch?v=j0iycybdzfa', 'text': None}, {'type': 'text', 'text': '\n\n\ncontest link:'}, {'type': 'link', 'url': 'https://www.hackerrank.com/Joanne-academy-batch-6-challenge-Joanne', 'text': None}, {'type': 'text', 'text': '\n\nhave fun!!!!!!!'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '10b2063307e9', 'image_72': 'https://avatars.slack-edge.com/2022-08-18/3958997027442_10b2063307e91bfe2157_72.png', 'first_name': 'Dawn', 'real_name': 'Dawn Green', 'display_name': 'Dawn Green', 'team': 'T03U4J8HMUG', 'name': 'Dawn', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://medium.com/basecs/from-theory-to-practice-representing-graphs-cfd782c5be38', 'ts': 1505144910, 'image_url': 'https://miro.medium.com/max/1200/1*1fcrjvjsorhfoh9usthaxq.jpeg', 'image_width': 671, 'image_height': 250, 'image_bytes': 73367, 'service_icon': 'https://miro.medium.com/fit/c/152/152/1*shhtyhace2uc3iu0igkwiq.png', 'id': 1, 'original_url': 'https://medium.com/basecs/from-theory-to-practice-representing-graphs-cfd782c5be38', 'fallback': 'medium: from theory to practice: representing graphs', 'text': 'the best investment you can make in your own learning is returning back to to the things you (think) you already know, and this is…', 'title': 'from theory to practice: representing graphs', 'title_link': 'https://medium.com/basecs/from-theory-to-practice-representing-graphs-cfd782c5be38', 'service_name': 'medium', 'fields': [{'value': '15 min read', 'title': 'Reading time', 'short': True}], 'message_blocks': None}, {'from_url': 'https://medium.com/basecs/deep-dive-through-a-graph-dfs-traversal-8177df5d0f13', 'ts': 1506339061, 'image_url': 'https://miro.medium.com/max/1200/1*gb8xfmh7x8fjnimexk4uhg.jpeg', 'image_width': 469, 'image_height': 250, 'image_bytes': 112970, 'service_icon': 'https://miro.medium.com/fit/c/152/152/1*shhtyhace2uc3iu0igkwiq.png', 'id': 2, 'original_url': 'https://medium.com/basecs/deep-dive-through-a-graph-dfs-traversal-8177df5d0f13', 'fallback': 'medium: deep dive through a graph: dfs traversal', 'text': 'for better or for worse, there’s always more than one way to do something. luckily for us, in the world of software and computer science…', 'title': 'deep dive through a graph: dfs traversal', 'title_link': 'https://medium.com/basecs/deep-dive-through-a-graph-dfs-traversal-8177df5d0f13', 'service_name': 'medium', 'fields': [{'value': '17 min read', 'title': 'Reading time', 'short': True}], 'message_blocks': None}, {'from_url': 'https://www.youtube.com/watch?v=j0iycybdzfa', 'thumb_url': 'https://i.ytimg.com/vi/j0iycybdzfa/hqdefault.jpg', 'thumb_width': 480, 'thumb_height':  ...
# {'type': 'message', 'text': 'guys anyone who has experience with this problem, help me? i am tired of it searching over the internet.', 'files': [{'id': 'F0427RQP83B', 'created': 1662800681, 'timestamp': 1662800681, 'name': 'Screenshot from 2022-09-10 12-03-11.png', 'title': 'Screenshot from 2022-09-10 12-03-11.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U03U9EJR362', 'user_team': 'T03U4J8HMUG', 'editable': False, 'size': 26314, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T03U4J8HMUG-F0427RQP83B/screenshot_from_2022-09-10_12-03-11.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'url_private_download': 'https://files.slack.com/files-pri/T03U4J8HMUG-F0427RQP83B/download/screenshot_from_2022-09-10_12-03-11.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'media_display_type': 'unknown', 'thumb_64': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_64.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_80': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_80.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_360.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360_w': 360, 'thumb_360_h': 40, 'thumb_480': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_480.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_480_w': 480, 'thumb_480_h': 53, 'thumb_160': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_160.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_720': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_720.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_720_w': 720, 'thumb_720_h': 79, 'thumb_800': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F0427RQP83B-f52255503a/screenshot_from_2022-09-10_12-03-11_800.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_800_w': 800, 'thumb_800_h': 88, 'original_w': 863, 'original_h': 95, 'thumb_tiny': 'AwAFADCnRRRQMSiiigAoPSig9KAP/9k=', 'permalink': 'https://10academybatch6.slack.com/files/U03U9EJR362/F0427RQP83B/screenshot_from_2022-09-10_12-03-11.png', 'permalink_public': 'https://slack-files.com/T03U4J8HMUG-F0427RQP83B-9fbc00927a', 'is_starred': False, 'has_rich_preview': False, 'file_access': 'visible'}], 'upload': False, 'user': 'U03U9EJR362', 'display_as_bot': False, 'ts': '1662800956.781899', 'blocks': [{'type': 'rich_text', 'block_id': '6eiek', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'guys anyone who has experience with this problem, help me? i am tired of it searching over the internet.'}]}]}], 'client_msg_id': 'd67cb92f-2426-453a-9767-a3144cc1cc49', 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1662981898.691299', 'user': 'U03U9EJR362', 'text': '<@u03u9ejr362> has joined the channel', 'blocks': None, 'attachments': None}
# {'client_msg_id': 'c28f8db4-45bb-46e4-954a-cdf8c10e834c', 'type': 'message', 'text': "<!here> we're on gmeet...if you're online join us", 'user': 'U03UJGP0C68', 'ts': '1663139588.116659', 'blocks': [{'type': 'rich_text', 'block_id': 'F8p/', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'here'}, {'type': 'text', 'text': " we're on gmeet...if you're online join us"}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '259faccdce43', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3965145363573_259faccdce439a8c6345_72.png', 'first_name': 'Tammy', 'real_name': 'Tammy Foster', 'display_name': 'Tammy Foster', 'team': 'T03U4J8HMUG', 'name': 'Tammy', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': '7f673168-cb68-42f4-929e-53ba6302b411', 'type': 'message', 'text': 'hello, can we make it at Joanne:15?', 'user': 'U03UUP56MDF', 'ts': '1663138877.355179', 'blocks': [{'type': 'rich_text', 'block_id': '1sQk8', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'hello, can we make it at Joanne:15?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'g00725318689', 'image_72': 'https://secure.gravatar.com/avatar/007253186898705d4f28c384188b8a63.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-72.png', 'first_name': 'Margaret', 'real_name': 'Margaret Jackson', 'display_name': 'Margaret Jackson', 'team': 'T03U4J8HMUG', 'name': 'Margaret', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': 'b1db43bd-5059-44f7-89be-4eb51f706094', 'type': 'message', 'text': 'delete the data from Michelle', 'user': 'U03UUN8M4RX', 'ts': '1664366548.344239', 'blocks': [{'type': 'rich_text', 'block_id': 'vaz', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'delete the data from Michelle'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'bc5543c34cbf', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3965164038549_bc5543c34cbf4cc3f27d_72.png', 'first_name': 'Matthew', 'real_name': 'Matthew Rodriguez', 'display_name': 'Matthew Rodriguez', 'team': 'T03U4J8HMUG', 'name': 'Matthew', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1664197292.152259', 'parent_user_id': 'U03UUN8M4RX', 'reactions': [{'name': 'white_check_mark', 'users': ['U03UJGP0C68'], 'count': 1}], 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1663006582.261019', 'user': 'U03UG0YHAUT', 'text': '<@u03ug0yhaut> has joined the channel', 'blocks': None, 'attachments': None}
# {'type': 'message', 'text': 'or you can find it on the explorer blow the network dir:', 'files': [{'id': 'F043MFB6A0H', 'created': 1663743662, 'timestamp': 1663743662, 'name': 'image.png', 'title': 'image.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U03UD68RQH3', 'user_team': 'T03U4J8HMUG', 'editable': False, 'size': 6105, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T03U4J8HMUG-F043MFB6A0H/image.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'url_private_download': 'https://files.slack.com/files-pri/T03U4J8HMUG-F043MFB6A0H/download/image.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'media_display_type': 'unknown', 'thumb_64': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F043MFB6A0H-81cd8360e4/image_64.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_80': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F043MFB6A0H-81cd8360e4/image_80.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F043MFB6A0H-81cd8360e4/image_360.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'thumb_360_w': 152, 'thumb_360_h': 160, 'thumb_160': 'https://files.slack.com/files-tmb/T03U4J8HMUG-F043MFB6A0H-81cd8360e4/image_160.png?t=xoxe-3956620599968-6240746766294-6247387524178-110fc6768eefd7fcb909c4550875ed49', 'original_w': 152, 'original_h': 160, 'thumb_tiny': 'AwAwAC2iCAyn86e7RsRtXb69aYACQM9f0qe4hjjdQpIznOSDQBEBF3LUDy8c5/CjYuRz29qPLH/PRaAA+X82PwzTGxnjpTwgwPm5NR0AOVGYEqMgdaSnRyGMkjoeopRMwJOAcnPNAupHRUnnH+6v5UjuXxkDj0oGMooooAlgi86TbuCjHU00JnqQCDg5plFAD2TaM7gfpTKKKACiiigD/9k=', 'permalink': 'https://10academybatch6.slack.com/files/U03UD68RQH3/F043MFB6A0H/image.png', 'permalink_public': 'https://slack-files.com/T03U4J8HMUG-F043MFB6A0H-0782dff981', 'is_starred': False, 'has_rich_preview': False, 'file_access': 'visible'}], 'upload': False, 'user': 'U03UD68RQH3', 'display_as_bot': False, 'ts': '1663743668.906829', 'blocks': [{'type': 'rich_text', 'block_id': '577P1', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'or you can find it on the explorer blow the network dir:'}]}]}], 'client_msg_id': '6aee40a6-3a95-4fdb-bb83-6de47fb39d1c', 'thread_ts': '1663742133.135979', 'parent_user_id': 'U03UJH1EQQL', 'attachments': None}
# {'client_msg_id': '55ccde73-1402-4328-af41-5f73441d460d', 'type': 'message', 'text': '<@u03ujgp0c68> thanks for the update. any link to the guide that i can follow?', 'user': 'U03UJN29Y4C', 'ts': '1664348537.687599', 'blocks': [{'type': 'rich_text', 'block_id': 'LHhv', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'user', 'user_id': 'U03UJGP0C68'}, {'type': 'text', 'text': ' thanks for the update. any link to the guide that i can follow?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '9bf024280cf1', 'image_72': 'https://avatars.slack-edge.com/2022-10-08/4190947116101_9bf024280cf14dffb003_72.jpg', 'first_name': 'Cynthia', 'real_name': 'Cynthia Davis', 'display_name': 'Cynthia Davis', 'team': 'T03U4J8HMUG', 'name': 'Cynthia', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1664290163.694309', 'parent_user_id': 'U03UJN29Y4C', 'attachments': None}
# {'client_msg_id': '5512e549-a529-46f6-9637-e423035d8fbd', 'type': 'message', 'text': 'thanks', 'user': 'U03UH397319', 'ts': '1665039674.444429', 'blocks': [{'type': 'rich_text', 'block_id': 'W7mvw', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'thanks'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Monica', 'real_name': 'Monica Newton', 'display_name': 'Monica Newton', 'team': 'T03U4J8HMUG', 'name': 'Monica', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1664992214.505379', 'parent_user_id': 'U03UH397319', 'attachments': None}
# {'client_msg_id': 'b820070c-5c39-4f0c-8086-32c0190d4f00', 'type': 'message', 'text': '*<!here>* good morning our meeting has started, please join using the link.\n<https://meet.Stephanie.com/qab-dyzj-ozp>', 'user': 'U03UUP56MDF', 'ts': '1665558254.668279', 'blocks': [{'type': 'rich_text', 'block_id': '6nDr', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'here', 'style': {'bold': True}}, {'type': 'text', 'text': ' good morning our meeting has started, please join using the link.\n'}, {'type': 'link', 'url': 'https://meet.Stephanie.com/qab-dyzj-ozp', 'text': None}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'g00725318689', 'image_72': 'https://secure.gravatar.com/avatar/007253186898705d4f28c384188b8a63.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-72.png', 'first_name': 'Margaret', 'real_name': 'Margaret Jackson', 'display_name': 'Margaret Jackson', 'team': 'T03U4J8HMUG', 'name': 'Margaret', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://meet.Stephanie.com/qab-dyzj-ozp', 'thumb_url': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v1/web-96dp/logo_meet_2020q4_color_2x_web_96dp.png', 'thumb_width': 192, 'thumb_height': 192, 'service_icon': 'http://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v1/web-24dp/logo_meet_2020q4_color_1x_web_24dp.png', 'id': 1, 'original_url': 'https://meet.Stephanie.com/qab-dyzj-ozp', 'fallback': 'meet', 'text': 'real-time meetings by Stephanie. using your browser, share your video, desktop, and presentations with teammates and customers.', 'title': 'meet', 'title_link': 'https://meet.Stephanie.com/qab-dyzj-ozp', 'service_name': 'meet.Stephanie.com', 'message_blocks': None}]}
# {'client_msg_id': '5E73152D-37DF-4922-A933-1BD42107266E', 'type': 'message', 'text': 'that is the maximum quality we received from Stephanie. however, you can check your network ', 'user': 'U03TEPYRM2P', 'ts': '1665558349.600599', 'blocks': [{'type': 'rich_text', 'block_id': 'QipGN', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'that '}, {'type': 'text', 'text': 'is the maximum quality'}, {'type': 'text', 'text': ' we '}, {'type': 'text', 'text': 'received'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'text': 'from Stephanie.'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'text': 'however,'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'text': 'you '}, {'type': 'text', 'text': 'can '}, {'type': 'text', 'text': 'check'}, {'type': 'text', 'text': ' '}, {'type': 'text', 'text': 'your network'}, {'type': 'text', 'text': ' '}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'f113df20f89c', 'image_72': 'https://avatars.slack-edge.com/2022-08-23/3977820714178_f113df20f89c894062b4_72.jpg', 'first_name': 'Bridget', 'real_name': 'Bridget Glover', 'display_name': 'Bridget Glover', 'team': 'T03U4J8HMUG', 'name': 'Bridget', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1665501880.342719', 'parent_user_id': 'U03UG5VFN03', 'attachments': None}
# {'client_msg_id': '004dc6c3-5ca9-4f38-bbc8-b26411c5ce97', 'type': 'message', 'text': '<@u03ujgp0c68> <@u03uur571a5> <@u03v785nlsu> presented to olutosin and killed it.  he was super impressed.\n\nbig congrats to all of you guys.', 'user': 'U03U93GNNVB', 'ts': '1666962823.974699', 'blocks': [{'type': 'rich_text', 'block_id': 'WZh0', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'user', 'user_id': 'U03UJGP0C68'}, {'type': 'text', 'text': ' '}, {'type': 'user', 'user_id': 'U03UUR571A5'}, {'type': 'text', 'text': ' '}, {'type': 'user', 'user_id': 'U03V785NLSU'}, {'type': 'text', 'text': ' presented to olutosin and killed it.  he was super impressed.\n\nbig congrats to all of you guys.'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'a49779ad093d', 'image_72': 'https://avatars.slack-edge.com/2022-08-22/3994045204528_a49779ad093d4fc39a87_72.jpg', 'first_name': 'Lawrence', 'real_name': 'Lawrence Braun', 'display_name': 'Lawrence Braun', 'team': 'T03U4J8HMUG', 'name': 'Lawrence', 'is_restricted': False, 'is_ultra_restricted': False}, 'reactions': [{'name': 'raised_hands::skin-tone-4', 'users': ['U03UG4Q7V42'], 'count': 1}, {'name': 'raised_hands', 'users': ['U03UD68RQH3', 'U03UG32J3PC', 'U03UJGRN5E0', 'U03UG0SFHGT', 'U03V61VGQG0', 'U03U1J51VFZ', 'U03U1FNPEUX', 'U03V6HMRPGQ', 'U03TT5KEYCF', 'U03UG5VFN03', 'U03UFV7HFNF', 'U03TEPYRM2P'], 'count': 12}, {'name': 'clap', 'users': ['U03UVHCV6KB', 'U03U1FNPEUX', 'U03UHB8CXDY', 'U03UAKATQ22'], 'count': 4}, {'name': 'fire', 'users': ['U03TT5KEYCF', 'U03UJN29Y4C', 'U03T89ACUUW', 'U03V8LHPDME'], 'count': 4}, {'name': 'dancer', 'users': ['U03TT5KEYCF'], 'count': 1}, {'name': 'clap::skin-tone-3', 'users': ['U03U9EJR362'], 'count': 1}, {'name': '+1', 'users': ['U03UUMR26Q1'], 'count': 1}], 'attachments': None}
# {'client_msg_id': '6a1af54a-eaf6-4961-bc02-a9b4a95e9cb8', 'type': 'message', 'text': 'anyone who has been able to test the casino contract on remix?', 'user': 'U03UH397319', 'ts': '1666942404.209919', 'blocks': [{'type': 'rich_text', 'block_id': 'Vyon', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'anyone who has been able to test the casino contract on remix?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Monica', 'real_name': 'Monica Newton', 'display_name': 'Monica Newton', 'team': 'T03U4J8HMUG', 'name': 'Monica', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': 'A30DE6AB-65D5-4846-8C35-20864F951B61', 'type': 'message', 'text': '<@u03u9ejr362> i can’t, i’m in a noisy place atm.', 'user': 'U03V785NLSU', 'ts': '1667809745.890659', 'blocks': [{'type': 'rich_text', 'block_id': 'E7eLx', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'user', 'user_id': 'U03U9EJR362'}, {'type': 'text', 'text': ' i can’t, i’m in a noisy place atm.'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '48d5c88821e9', 'image_72': 'https://avatars.slack-edge.com/2022-08-21/3993277785968_48d5c88821e922581e17_72.jpg', 'first_name': 'Jason', 'real_name': 'Jason Burnett', 'display_name': 'Jason Burnett', 'team': 'T03U4J8HMUG', 'name': 'Jason', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1667807598.812679', 'parent_user_id': 'U03U9EJR362', 'reactions': [{'name': '+1::skin-tone-3', 'users': ['U03U9EJR362'], 'count': 1}], 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1666944615.490839', 'user': 'U03T89ACUUW', 'text': '<@u03t89acuuw> has joined the channel', 'blocks': None, 'attachments': None}
# {'client_msg_id': 'b755e4ae-7b81-45b8-98a3-b56ee6845af4', 'type': 'message', 'text': '<!channel> the aws instances are up and running . you can use your new group number to connect. follow the same process as before.\n<https://www.notion.so/Joanneacademy/process-of-connecting-with-ssh-58540d9a95ce44e482365b17eec2cd4c>', 'user': 'U03U9DB7REG', 'ts': '1667295481.102109', 'blocks': [{'type': 'rich_text', 'block_id': 'rWPi', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'channel'}, {'type': 'text', 'text': ' the aws instances are up and running . you can use your new group number to connect. follow the same process as before.\n'}, {'type': 'link', 'url': 'https://www.notion.so/Joanneacademy/process-of-connecting-with-ssh-58540d9a95ce44e482365b17eec2cd4c', 'text': None}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '10b2063307e9', 'image_72': 'https://avatars.slack-edge.com/2022-08-18/3958997027442_10b2063307e91bfe2157_72.png', 'first_name': 'Dawn', 'real_name': 'Dawn Green', 'display_name': 'Dawn Green', 'team': 'T03U4J8HMUG', 'name': 'Dawn', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://www.notion.so/Joanneacademy/process-of-connecting-with-ssh-58540d9a95ce44e482365b17eec2cd4c', 'service_icon': 'https://www.notion.so/images/favicon.ico', 'id': 1, 'original_url': 'https://www.notion.so/Joanneacademy/process-of-connecting-with-ssh-58540d9a95ce44e482365b17eec2cd4c', 'fallback': 'Joanne academy on notion: process of connecting with ssh', 'text': 'configuration', 'title': 'process of connecting with ssh', 'title_link': 'https://www.notion.so/Joanneacademy/process-of-connecting-with-ssh-58540d9a95ce44e482365b17eec2cd4c', 'service_name': 'Joanne academy on notion', 'message_blocks': None}], 'thread_ts': '1667295481.102109', 'reply_count': 9, 'reply_users_count': 7, 'latest_reply': '1667306066.095919', 'reply_users': ['U03UJGP0C68', 'U03U1HAG9TR', 'U03U9DB7REG', 'U03UHB8CXDY', 'U03UKL27B0R', 'U03UJGRN5E0', 'U03V6HMRPGQ'], 'replies': [{'user': 'U03UJGP0C68', 'ts': '1667295587.688679'}, {'user': 'U03U1HAG9TR', 'ts': '1667295707.437219'}, {'user': 'U03U9DB7REG', 'ts': '1667295897.091239'}, {'user': 'U03UJGP0C68', 'ts': '1667295913.818559'}, {'user': 'U03U1HAG9TR', 'ts': '1667296394.901949'}, {'user': 'U03UHB8CXDY', 'ts': '1667296411.655179'}, {'user': 'U03UKL27B0R', 'ts': '1667297572.515879'}, {'user': 'U03UJGRN5E0', 'ts': '1667298190.230289'}, {'user': 'U03V6HMRPGQ', 'ts': '1667306066.095919'}], 'is_locked': False, 'subscribed': False}
# {'client_msg_id': '9441f8a0-ae63-486c-b054-8fc15fa9448d', 'type': 'message', 'text': '<!here>,they are some not famiErinr faces, i think they are adluido', 'user': 'U03V6HMRPGQ', 'ts': '1667808788.355859', 'blocks': [{'type': 'rich_text', 'block_id': 'B7L4t', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'here'}, {'type': 'text', 'text': ',they are some not famiErinr faces, i think they are adluido'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '23fcf5329c03', 'image_72': 'https://avatars.slack-edge.com/2022-08-22/3969139924917_23fcf5329c03131c761f_72.png', 'first_name': 'Lisa', 'real_name': 'Lisa Dickerson', 'display_name': 'Lisa Dickerson', 'team': 'T03U4J8HMUG', 'name': 'Lisa', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': '8b776b29-0792-4e08-8665-67ed86cbe5eb', 'type': 'message', 'text': 'hello everyone!!', 'user': 'U03UD4FEDHB', 'ts': '1667286036.062869', 'blocks': [{'type': 'rich_text', 'block_id': 'V4v/Q', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'hello everyone!!'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'g48fef055f8a', 'image_72': 'https://secure.gravatar.com/avatar/48fef055f8a8b8a4c0bcfefbf5e3eec3.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-72.png', 'first_name': 'Michael', 'real_name': 'Michael Fowler', 'display_name': 'Michael Fowler', 'team': 'T03U4J8HMUG', 'name': 'Michael', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': '76430974-41f5-4802-b5f8-9bf5b216386a', 'type': 'message', 'text': 'how could i use dvc to get data from Johnson to colabe notebook', 'user': 'U03V6HMRPGQ', 'ts': '1668238822.775769', 'blocks': [{'type': 'rich_text', 'block_id': 'Fckg', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'how could i use dvc to get data from Johnson to colabe notebook'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '23fcf5329c03', 'image_72': 'https://avatars.slack-edge.com/2022-08-22/3969139924917_23fcf5329c03131c761f_72.png', 'first_name': 'Lisa', 'real_name': 'Lisa Dickerson', 'display_name': 'Lisa Dickerson', 'team': 'T03U4J8HMUG', 'name': 'Lisa', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1668238822.775769', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1668249288.668229', 'reply_users': ['U03UH397319'], 'replies': [{'user': 'U03UH397319', 'ts': '1668249288.668229'}], 'is_locked': False, 'subscribed': False, 'attachments': None}
# {'client_msg_id': '11af2ce0-737e-4d7c-9811-9bf810c62cdd', 'type': 'message', 'text': '<https://www.youtube.com/watch?v=6ria_qur2yo&amp;ab_channel=seattledataguy>', 'user': 'U03UVHCV6KB', 'ts': '1668751635.469589', 'blocks': [{'type': 'rich_text', 'block_id': 'eTv', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://www.youtube.com/watch?v=6ria_qur2yo&ab_channel=seattledataguy', 'text': None}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc9619121f99', 'image_72': 'https://secure.gravatar.com/avatar/c9619121f998ee4a7e46177f2a5729de.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-72.png', 'first_name': 'Gregory', 'real_name': 'Gregory Bowman', 'display_name': 'Gregory Bowman', 'team': 'T03U4J8HMUG', 'name': 'Gregory', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://www.youtube.com/watch?v=6ria_qur2yo&amp;ab_channel=seattledataguy', 'thumb_url': 'https://i.ytimg.com/vi/6ria_qur2yo/hqdefault.jpg', 'thumb_width': 480, 'thumb_height': 360, 'video_html': '<iframe width="400" height="225" src="https://www.youtube.com/embed/6ria_qur2yo?feature=oembed&autoplay=1&iv_load_policy=3" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen title="being a data engineer: expectations vs reality"></iframe>', 'video_html_width': 400, 'video_html_height': 225, 'service_icon': 'https://a.slack-edge.com/80588/img/unfurl_icons/youtube.png', 'id': 1, 'original_url': 'https://www.youtube.com/watch?v=6ria_qur2yo&amp;ab_channel=seattledataguy', 'fallback': 'youtube video: being a data engineer: expectations vs reality', 'title': 'being a data engineer: expectations vs reality', 'title_link': 'https://www.youtube.com/watch?v=6ria_qur2yo&amp;ab_channel=seattledataguy', 'author_name': 'seattle data guy', 'author_link': 'https://www.youtube.com/@seattledataguy', 'service_name': 'youtube', 'service_url': 'https://www.youtube.com/', 'message_blocks': None}]}
# {'client_msg_id': '4f008f4e-a72b-4453-a9a9-4909342078eb', 'type': 'message', 'text': 'please share the week document <@u03uun8m4rx>', 'user': 'U03UH397319', 'ts': '1667817586.333899', 'blocks': [{'type': 'rich_text', 'block_id': 'n33', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'please share the week document '}, {'type': 'user', 'user_id': 'U03UUN8M4RX'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Monica', 'real_name': 'Monica Newton', 'display_name': 'Monica Newton', 'team': 'T03U4J8HMUG', 'name': 'Monica', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': None}
# {'client_msg_id': '92547372-8bfb-408f-8a0d-451c22f83bfd', 'type': 'message', 'text': '<https://developer.algorand.org/solutions/minting-nfts-on-algorand-using-ipfs/>', 'user': 'U03UJGRN5E0', 'ts': '1668359175.400459', 'blocks': [{'type': 'rich_text', 'block_id': 'I1D', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://developer.algorand.org/solutions/minting-nfts-on-algorand-using-ipfs/', 'text': None}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '35b05758f532', 'image_72': 'https://avatars.slack-edge.com/2022-09-30/4156429070997_35b05758f532bdef5b5f_72.jpg', 'first_name': 'Dennis', 'real_name': 'Dennis Parker', 'display_name': 'Dennis Parker', 'team': 'T03U4J8HMUG', 'name': 'Dennis', 'is_restricted': False, 'is_ultra_restricted': False}, 'attachments': [{'from_url': 'https://developer.algorand.org/solutions/minting-nfts-on-algorand-using-ipfs/', 'image_url': 'https://algorand-developer-portal.tryprism.com/static/posts/2021/11/06 05:24/algorand-ipfs.jpg?w=1200&cmd=resize_then_crop&height=630&quality=70', 'image_width': 476, 'image_height': 250, 'image_bytes': 119776, 'service_icon': 'https://algorand-devloper-portal-app.s3.amazonaws.com/static/img/favicon.png', 'id': 1, 'original_url': 'https://developer.algorand.org/solutions/minting-nfts-on-algorand-using-ipfs/', 'fallback': 'minting nfts on algorand using ipfs', 'text': 'a diy code solution and guide on how to work with nfts (subset of algorand asas), using decentralized digital assets hosted and pinned on ipfs, in c…', 'title': 'minting nfts on algorand using ipfs', 'title_link': 'https://developer.algorand.org/solutions/minting-nfts-on-algorand-using-ipfs/', 'service_name': 'developer.algorand.org', 'message_blocks': None}]}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1668759897.611609', 'user': 'U03UL5LSTG9', 'text': '<@u03ul5lstg9> has joined the channel', 'blocks': None, 'attachments': None}
# {'type': 'message', 'subtype': 'channel_join', 'ts': '1668760175.262229', 'user': 'U03UL5LSTG9', 'text': '<@u03ul5lstg9> has joined the channel', 'reactions': [{'name': 'raised_hands', 'users': ['U03UVHCV6KB'], 'count': 1}], 'blocks': None, 'attachments': None}
# [ObjectId('6569b5a114c3b0d37a81b057'),
#  ObjectId('6569b5a114c3b0d37a81b058'),
#  ObjectId('6569b5a114c3b0d37a81b059'),
#  ObjectId('6569b5a114c3b0d37a81b05a'),
#  ObjectId('6569b5a114c3b0d37a81b05b'),
#  ObjectId('6569b5a114c3b0d37a81b05c'),
#  ObjectId('6569b5a114c3b0d37a81b05d'),
#  ObjectId('6569b5a114c3b0d37a81b05e'),
#  ObjectId('6569b5a114c3b0d37a81b05f'),
#  ObjectId('6569b5a114c3b0d37a81b060'),
#  ObjectId('6569b5a114c3b0d37a81b061'),
#  ObjectId('6569b5a114c3b0d37a81b062'),
#  ObjectId('6569b5a114c3b0d37a81b063'),
#  ObjectId('6569b5a114c3b0d37a81b064'),
#  ObjectId('6569b5a114c3b0d37a81b065'),
#  ObjectId('6569b5a114c3b0d37a81b066'),
#  ObjectId('6569b5a114c3b0d37a81b067'),
#  ObjectId('6569b5a114c3b0d37a81b068'),
#  ObjectId('6569b5a114c3b0d37a81b069'),
#  ObjectId('6569b5a114c3b0d37a81b06a'),
#  ObjectId('6569b5a114c3b0d37a81b06b'),
#  ObjectId('6569b5a114c3b0d37a81b06c'),
#  ObjectId('6569b5a114c3b0d37a81b06d'),
#  ObjectId('6569b5a114c3b0d37a81b06e'),
#  ObjectId('6569b5a114c3b0d37a81b06f'),
#  ObjectId('6569b5a114c3b0d37a81b070'),
#  ObjectId('6569b5a114c3b0d37a81b071'),
#  ObjectId('6569b5a114c3b0d37a81b072'),
#  ObjectId('6569b5a114c3b0d37a81b073'),
#  ObjectId('6569b5a114c3b0d37a81b074'),
#  ObjectId('6569b5a114c3b0d37a81b075'),
#  ObjectId('6569b5a114c3b0d37a81b076'),
#  ObjectId('6569b5a114c3b0d37a81b077'),
#  ObjectId('6569b5a114c3b0d37a81b078'),
#  ObjectId('6569b5a114c3b0d37a81b079'),
#  ObjectId('6569b5a114c3b0d37a81b07a'),
#  ObjectId('6569b5a114c3b0d37a81b07b'),
#  ObjectId('6569b5a114c3b0d37a81b07c'),
#  ObjectId('6569b5a114c3b0d37a81b07d'),
#  ObjectId('6569b5a114c3b0d37a81b07e'),
#  ObjectId('6569b5a114c3b0d37a81b07f'),
#  ObjectId('6569b5a114c3b0d37a81b080'),
#  ObjectId('6569b5a114c3b0d37a81b081'),
#  ObjectId('6569b5a114c3b0d37a81b082'),
#  ObjectId('6569b5a114c3b0d37a81b083'),
#  ObjectId('6569b5a114c3b0d37a81b084'),
#  ObjectId('6569b5a114c3b0d37a81b085'),
#  ObjectId('6569b5a114c3b0d37a81b086'),
#  ObjectId('6569b5a114c3b0d37a81b087'),
#  ObjectId('6569b5a114c3b0d37a81b088'),
#  ObjectId('6569b5a114c3b0d37a81b089'),
#  ObjectId('6569b5a114c3b0d37a81b08a'),
#  ObjectId('6569b5a114c3b0d37a81b08b'),
#  ObjectId('6569b5a114c3b0d37a81b08c'),
#  ObjectId('6569b5a114c3b0d37a81b08d'),
#  ObjectId('6569b5a114c3b0d37a81b08e'),
#  ObjectId('6569b5a114c3b0d37a81b08f'),
#  ObjectId('6569b5a114c3b0d37a81b090'),
#  ObjectId('6569b5a114c3b0d37a81b091'),
#  ObjectId('6569b5a114c3b0d37a81b092'),
#  ObjectId('6569b5a114c3b0d37a81b093'),
#  ObjectId('6569b5a114c3b0d37a81b094'),
#  ObjectId('6569b5a114c3b0d37a81b095'),
#  ObjectId('6569b5a114c3b0d37a81b096'),
#  ObjectId('6569b5a114c3b0d37a81b097'),
#  ObjectId('6569b5a114c3b0d37a81b098'),
#  ObjectId('6569b5a114c3b0d37a81b099'),
#  ObjectId('6569b5a114c3b0d37a81b09a'),
#  ObjectId('6569b5a114c3b0d37a81b09b'),
#  ObjectId('6569b5a114c3b0d37a81b09c'),
#  ObjectId('6569b5a114c3b0d37a81b09d'),
#  ObjectId('6569b5a114c3b0d37a81b09e'),
# ...
#  ObjectId('6569b5a114c3b0d37a81b2a5'),
#  ObjectId('6569b5a114c3b0d37a81b2a6'),
#  ObjectId('6569b5a114c3b0d37a81b2a7'),
#  ObjectId('6569b5a114c3b0d37a81b2a8'),
#  ObjectId('6569b5a114c3b0d37a81b2a9'),
#  ObjectId('6569b5a114c3b0d37a81b2aa'),
#  ObjectId('6569b5a114c3b0d37a81b2ab'),
#  ObjectId('6569b5a114c3b0d37a81b2ac'),
#  ObjectId('6569b5a114c3b0d37a81b2ad'),
#  ObjectId('6569b5a114c3b0d37a81b2ae'),
#  ObjectId('6569b5a114c3b0d37a81b2af'),
#  ObjectId('6569b5a114c3b0d37a81b2b0'),
#  ObjectId('6569b5a114c3b0d37a81b2b1'),
#  ObjectId('6569b5a114c3b0d37a81b2b2'),
#  ObjectId('6569b5a114c3b0d37a81b2b3'),
#  ObjectId('6569b5a114c3b0d37a81b2b4'),
#  ObjectId('6569b5a114c3b0d37a81b2b5'),
#  ObjectId('6569b5a114c3b0d37a81b2b6'),
#  ObjectId('6569b5a114c3b0d37a81b2b7'),
#  ObjectId('6569b5a114c3b0d37a81b2b8'),
#  ObjectId('6569b5a114c3b0d37a81b2b9'),
#  ObjectId('6569b5a114c3b0d37a81b2ba'),
#  ObjectId('6569b5a114c3b0d37a81b2bb'),
#  ObjectId('6569b5a114c3b0d37a81b2bc'),
#  ObjectId('6569b5a114c3b0d37a81b2bd'),
#  ObjectId('6569b5a114c3b0d37a81b2be'),
#  ObjectId('6569b5a114c3b0d37a81b2bf'),
#  ObjectId('6569b5a114c3b0d37a81b2c0'),
#  ObjectId('6569b5a114c3b0d37a81b2c1'),
#  ObjectId('6569b5a114c3b0d37a81b2c2'),
#  ObjectId('6569b5a114c3b0d37a81b2c3'),
#  ObjectId('6569b5a114c3b0d37a81b2c4'),
#  ObjectId('6569b5a114c3b0d37a81b2c5'),
#  ObjectId('6569b5a114c3b0d37a81b2c6'),
#  ObjectId('6569b5a114c3b0d37a81b2c7'),
#  ObjectId('6569b5a114c3b0d37a81b2c8'),
#  ObjectId('6569b5a114c3b0d37a81b2c9'),
#  ObjectId('6569b5a114c3b0d37a81b2ca'),
#  ObjectId('6569b5a114c3b0d37a81b2cb'),
#  ObjectId('6569b5a114c3b0d37a81b2cc'),
#  ObjectId('6569b5a114c3b0d37a81b2cd'),
#  ObjectId('6569b5a114c3b0d37a81b2ce'),
#  ObjectId('6569b5a114c3b0d37a81b2cf'),
#  ObjectId('6569b5a114c3b0d37a81b2d0'),
#  ObjectId('6569b5a114c3b0d37a81b2d1'),
#  ObjectId('6569b5a114c3b0d37a81b2d2'),
#  ObjectId('6569b5a114c3b0d37a81b2d3'),
#  ObjectId('6569b5a114c3b0d37a81b2d4'),
#  ObjectId('6569b5a114c3b0d37a81b2d5'),
#  ObjectId('6569b5a114c3b0d37a81b2d6'),
#  ObjectId('6569b5a114c3b0d37a81b2d7'),
#  ObjectId('6569b5a114c3b0d37a81b2d8'),
#  ObjectId('6569b5a114c3b0d37a81b2d9'),
#  ObjectId('6569b5a114c3b0d37a81b2da'),
#  ObjectId('6569b5a114c3b0d37a81b2db'),
#  ObjectId('6569b5a114c3b0d37a81b2dc'),
#  ObjectId('6569b5a114c3b0d37a81b2dd'),
#  ObjectId('6569b5a114c3b0d37a81b2de'),
#  ObjectId('6569b5a114c3b0d37a81b2df'),
#  ObjectId('6569b5a114c3b0d37a81b2e0'),
#  ObjectId('6569b5a114c3b0d37a81b2e1'),
#  ObjectId('6569b5a114c3b0d37a81b2e2'),
#  ObjectId('6569b5a114c3b0d37a81b2e3'),
#  ObjectId('6569b5a114c3b0d37a81b2e4'),
#  ObjectId('6569b5a114c3b0d37a81b2e5'),
#  ObjectId('6569b5a114c3b0d37a81b2e6'),
#  ObjectId('6569b5a114c3b0d37a81b2e7'),
#  ObjectId('6569b5a114c3b0d37a81b2e8'),
#  ObjectId('6569b5a114c3b0d37a81b2e9'),
#  ObjectId('6569b5a114c3b0d37a81b2ea'),
#  ObjectId('6569b5a114c3b0d37a81b2eb'),
#  ObjectId('6569b5a114c3b0d37a81b2ec'),
#  ObjectId('6569b5a114c3b0d37a81b2ed'),
#  ObjectId('6569b5a114c3b0d37a81b2ee'),
#  ObjectId('6569b5a114c3b0d37a81b2ef'),
#  ObjectId('6569b5a114c3b0d37a81b2f0'),
#  ObjectId('6569b5a114c3b0d37a81b2f1'),
#  ObjectId('6569b5a114c3b0d37a81b2f2'),
#  ObjectId('6569b5a114c3b0d37a81b2f3'),
#  ObjectId('6569b5a114c3b0d37a81b2f4'),
#  ObjectId('6569b5a114c3b0d37a81b2f5'),
#  ObjectId('6569b5a114c3b0d37a81b2f6'),
#  ObjectId('6569b5a114c3b0d37a81b2f7'),
#  ObjectId('6569b5a114c3b0d37a81b2f8'),
#  ObjectId('6569b5a114c3b0d37a81b2f9'),
#  ObjectId('6569b5a114c3b0d37a81b2fa'),
#  ObjectId('6569b5a114c3b0d37a81b2fb'),
#  ObjectId('6569b5a114c3b0d37a81b2fc'),
#  ObjectId('6569b5a114c3b0d37a81b2fd'),
#  ObjectId('6569b5a114c3b0d37a81b2fe'),
#  ObjectId('6569b5a114c3b0d37a81b2ff'),
#  ObjectId('6569b5a114c3b0d37a81b300'),
#  ObjectId('6569b5a114c3b0d37a81b301'),
#  ObjectId('6569b5a114c3b0d37a81b302'),
#  ObjectId('6569b5a114c3b0d37a81b303'),
#  ObjectId('6569b5a114c3b0d37a81b304'),
#  ObjectId('6569b5a114c3b0d37a81b305'),
#  ObjectId('6569b5a114c3b0d37a81b306'),
#  ObjectId('6569b5a114c3b0d37a81b307'),
#  ObjectId('6569b5a114c3b0d37a81b308'),
#  ObjectId('6569b5a114c3b0d37a81b309'),
#  ObjectId('6569b5a114c3b0d37a81b30a'),
#  ObjectId('6569b5a114c3b0d37a81b30b'),
#  ObjectId('6569b5a114c3b0d37a81b30c'),
#  ObjectId('6569b5a114c3b0d37a81b30d'),
#  ObjectId('6569b5a114c3b0d37a81b30e'),
#  ObjectId('6569b5a114c3b0d37a81b30f'),
#  ObjectId('6569b5a114c3b0d37a81b310'),
#  ObjectId('6569b5a114c3b0d37a81b311'),
#  ObjectId('6569b5a114c3b0d37a81b312'),
#  ObjectId('6569b5a114c3b0d37a81b313'),
#  ObjectId('6569b5a114c3b0d37a81b314'),
#  ObjectId('6569b5a114c3b0d37a81b315'),
#  ObjectId('6569b5a114c3b0d37a81b316'),
#  ObjectId('6569b5a114c3b0d37a81b317'),
#  ObjectId('6569b5a114c3b0d37a81b318'),
#  ObjectId('6569b5a114c3b0d37a81b319'),
#  ObjectId('6569b5a114c3b0d37a81b31a'),
#  ObjectId('6569b5a114c3b0d37a81b31b'),
#  ObjectId('6569b5a114c3b0d37a81b31c'),
#  ObjectId('6569b5a114c3b0d37a81b31d'),
#  ObjectId('6569b5a114c3b0d37a81b31e'),
#  ObjectId('6569b5a114c3b0d37a81b31f'),
#  ObjectId('6569b5a114c3b0d37a81b320'),
#  ObjectId('6569b5a114c3b0d37a81b321'),
#  ObjectId('6569b5a114c3b0d37a81b322'),
#  ObjectId('6569b5a114c3b0d37a81b323'),
#  ObjectId('6569b5a114c3b0d37a81b324'),
#  ObjectId('6569b5a114c3b0d37a81b325'),
#  ObjectId('6569b5a114c3b0d37a81b326'),
#  ObjectId('6569b5a114c3b0d37a81b327'),
#  ObjectId('6569b5a114c3b0d37a81b328'),
#  ObjectId('6569b5a114c3b0d37a81b329'),
#  ObjectId('6569b5a114c3b0d37a81b32a'),
#  ObjectId('6569b5a114c3b0d37a81b32b'),
#  ObjectId('6569b5a114c3b0d37a81b32c'),
#  ObjectId('6569b5a114c3b0d37a81b32d'),
#  ObjectId('6569b5a114c3b0d37a81b32e'),
#  ObjectId('6569b5a114c3b0d37a81b32f'),
#  ObjectId('6569b5a114c3b0d37a81b330'),
#  ObjectId('6569b5a114c3b0d37a81b331'),
#  ObjectId('6569b5a114c3b0d37a81b332'),
#  ObjectId('6569b5a114c3b0d37a81b333'),
#  ObjectId('6569b5a114c3b0d37a81b334'),
#  ObjectId('6569b5a114c3b0d37a81b335'),
#  ObjectId('6569b5a114c3b0d37a81b336'),
#  ObjectId('6569b5a114c3b0d37a81b337'),
#  ObjectId('6569b5a114c3b0d37a81b338'),
#  ObjectId('6569b5a114c3b0d37a81b339'),
#  ObjectId('6569b5a114c3b0d37a81b33a'),
#  ObjectId('6569b5a114c3b0d37a81b33b'),
#  ObjectId('6569b5a114c3b0d37a81b33c'),
#  ObjectId('6569b5a114c3b0d37a81b33d'),
#  ObjectId('6569b5a114c3b0d37a81b33e'),
#  ObjectId('6569b5a114c3b0d37a81b33f'),
#  ObjectId('6569b5a114c3b0d37a81b340'),
#  ObjectId('6569b5a114c3b0d37a81b341'),
#  ObjectId('6569b5a114c3b0d37a81b342'),
#  ObjectId('6569b5a114c3b0d37a81b343'),
#  ObjectId('6569b5a114c3b0d37a81b344'),
#  ObjectId('6569b5a114c3b0d37a81b345'),
#  ObjectId('6569b5a114c3b0d37a81b346'),
#  ObjectId('6569b5a114c3b0d37a81b347'),
#  ObjectId('6569b5a114c3b0d37a81b348'),
#  ObjectId('6569b5a114c3b0d37a81b349'),
#  ObjectId('6569b5a114c3b0d37a81b34a'),
#  ObjectId('6569b5a114c3b0d37a81b34b'),
#  ObjectId('6569b5a114c3b0d37a81b34c'),
#  ObjectId('6569b5a114c3b0d37a81b34d'),
#  ObjectId('6569b5a114c3b0d37a81b34e'),
#  ObjectId('6569b5a114c3b0d37a81b34f'),
#  ObjectId('6569b5a114c3b0d37a81b350'),
#  ObjectId('6569b5a114c3b0d37a81b351'),
#  ObjectId('6569b5a114c3b0d37a81b352'),
#  ObjectId('6569b5a114c3b0d37a81b353'),
#  ObjectId('6569b5a114c3b0d37a81b354'),
#  ObjectId('6569b5a114c3b0d37a81b355'),
#  ObjectId('6569b5a114c3b0d37a81b356'),
#  ObjectId('6569b5a114c3b0d37a81b357'),
#  ObjectId('6569b5a114c3b0d37a81b358'),
#  ObjectId('6569b5a114c3b0d37a81b359'),
#  ObjectId('6569b5a114c3b0d37a81b35a'),
#  ObjectId('6569b5a114c3b0d37a81b35b'),
#  ObjectId('6569b5a114c3b0d37a81b35c'),
#  ObjectId('6569b5a114c3b0d37a81b35d'),
#  ObjectId('6569b5a114c3b0d37a81b35e'),
#  ObjectId('6569b5a114c3b0d37a81b35f'),
#  ObjectId('6569b5a114c3b0d37a81b360'),
#  ObjectId('6569b5a114c3b0d37a81b361'),
#  ObjectId('6569b5a114c3b0d37a81b362'),
#  ObjectId('6569b5a114c3b0d37a81b363'),
#  ObjectId('6569b5a114c3b0d37a81b364'),
#  ObjectId('6569b5a114c3b0d37a81b365'),
#  ObjectId('6569b5a114c3b0d37a81b366'),
#  ObjectId('6569b5a114c3b0d37a81b367'),
#  ObjectId('6569b5a114c3b0d37a81b368'),
#  ObjectId('6569b5a114c3b0d37a81b369'),
#  ObjectId('6569b5a114c3b0d37a81b36a'),
#  ObjectId('6569b5a114c3b0d37a81b36b'),
#  ObjectId('6569b5a114c3b0d37a81b36c'),
#  ObjectId('6569b5a114c3b0d37a81b36d'),
#  ObjectId('6569b5a114c3b0d37a81b36e'),
#  ObjectId('6569b5a114c3b0d37a81b36f'),
#  ObjectId('6569b5a114c3b0d37a81b370'),
#  ObjectId('6569b5a114c3b0d37a81b371'),
#  ObjectId('6569b5a114c3b0d37a81b372'),
#  ObjectId('6569b5a114c3b0d37a81b373'),
#  ObjectId('6569b5a114c3b0d37a81b374'),
#  ObjectId('6569b5a114c3b0d37a81b375'),
#  ObjectId('6569b5a114c3b0d37a81b376'),
#  ObjectId('6569b5a114c3b0d37a81b377'),
#  ObjectId('6569b5a114c3b0d37a81b378'),
#  ObjectId('6569b5a114c3b0d37a81b379'),
#  ObjectId('6569b5a114c3b0d37a81b37a'),
#  ObjectId('6569b5a114c3b0d37a81b37b'),
#  ObjectId('6569b5a114c3b0d37a81b37c'),
#  ObjectId('6569b5a114c3b0d37a81b37d'),
#  ObjectId('6569b5a114c3b0d37a81b37e'),
#  ObjectId('6569b5a114c3b0d37a81b37f'),
#  ObjectId('6569b5a114c3b0d37a81b380'),
#  ObjectId('6569b5a114c3b0d37a81b381'),
#  ObjectId('6569b5a114c3b0d37a81b382'),
#  ObjectId('6569b5a114c3b0d37a81b383'),
#  ObjectId('6569b5a114c3b0d37a81b384'),
#  ObjectId('6569b5a114c3b0d37a81b385'),
#  ObjectId('6569b5a114c3b0d37a81b386'),
#  ObjectId('6569b5a114c3b0d37a81b387'),
#  ObjectId('6569b5a114c3b0d37a81b388'),
#  ObjectId('6569b5a114c3b0d37a81b389'),
#  ObjectId('6569b5a114c3b0d37a81b38a'),
#  ObjectId('6569b5a114c3b0d37a81b38b'),
#  ObjectId('6569b5a114c3b0d37a81b38c'),
#  ObjectId('6569b5a114c3b0d37a81b38d'),
#  ObjectId('6569b5a114c3b0d37a81b38e'),
#  ObjectId('6569b5a114c3b0d37a81b38f'),
#  ObjectId('6569b5a114c3b0d37a81b390'),
#  ObjectId('6569b5a114c3b0d37a81b391'),
#  ObjectId('6569b5a114c3b0d37a81b392'),
#  ObjectId('6569b5a114c3b0d37a81b393'),
#  ObjectId('6569b5a114c3b0d37a81b394'),
#  ObjectId('6569b5a114c3b0d37a81b395'),
#  ObjectId('6569b5a114c3b0d37a81b396'),
#  ObjectId('6569b5a114c3b0d37a81b397'),
#  ObjectId('6569b5a114c3b0d37a81b398'),
#  ObjectId('6569b5a114c3b0d37a81b399'),
#  ObjectId('6569b5a114c3b0d37a81b39a'),
#  ObjectId('6569b5a114c3b0d37a81b39b'),
#  ObjectId('6569b5a114c3b0d37a81b39c'),
#  ObjectId('6569b5a114c3b0d37a81b39d'),
#  ObjectId('6569b5a114c3b0d37a81b39e'),
#  ObjectId('6569b5a114c3b0d37a81b39f'),
#  ObjectId('6569b5a114c3b0d37a81b3a0'),
#  ObjectId('6569b5a114c3b0d37a81b3a1'),
#  ObjectId('6569b5a114c3b0d37a81b3a2'),
#  ObjectId('6569b5a114c3b0d37a81b3a3'),
#  ObjectId('6569b5a114c3b0d37a81b3a4'),
#  ObjectId('6569b5a114c3b0d37a81b3a5'),
#  ObjectId('6569b5a114c3b0d37a81b3a6'),
#  ObjectId('6569b5a114c3b0d37a81b3a7'),
#  ObjectId('6569b5a114c3b0d37a81b3a8'),
#  ObjectId('6569b5a114c3b0d37a81b3a9'),
#  ObjectId('6569b5a114c3b0d37a81b3aa'),
#  ObjectId('6569b5a114c3b0d37a81b3ab'),
#  ObjectId('6569b5a114c3b0d37a81b3ac'),
#  ObjectId('6569b5a114c3b0d37a81b3ad'),
#  ObjectId('6569b5a114c3b0d37a81b3ae'),
#  ObjectId('6569b5a114c3b0d37a81b3af'),
#  ObjectId('6569b5a114c3b0d37a81b3b0'),
#  ObjectId('6569b5a114c3b0d37a81b3b1'),
#  ObjectId('6569b5a114c3b0d37a81b3b2'),
#  ObjectId('6569b5a114c3b0d37a81b3b3'),
#  ObjectId('6569b5a114c3b0d37a81b3b4'),
#  ObjectId('6569b5a114c3b0d37a81b3b5'),
#  ObjectId('6569b5a114c3b0d37a81b3b6'),
#  ObjectId('6569b5a114c3b0d37a81b3b7'),
#  ObjectId('6569b5a114c3b0d37a81b3b8'),
#  ObjectId('6569b5a114c3b0d37a81b3b9'),
#  ObjectId('6569b5a114c3b0d37a81b3ba'),
#  ObjectId('6569b5a114c3b0d37a81b3bb'),
#  ObjectId('6569b5a114c3b0d37a81b3bc'),
#  ObjectId('6569b5a114c3b0d37a81b3bd'),
#  ObjectId('6569b5a114c3b0d37a81b3be'),
#  ObjectId('6569b5a114c3b0d37a81b3bf'),
#  ObjectId('6569b5a114c3b0d37a81b3c0'),
#  ObjectId('6569b5a114c3b0d37a81b3c1'),
#  ObjectId('6569b5a114c3b0d37a81b3c2'),
#  ObjectId('6569b5a114c3b0d37a81b3c3'),
#  ObjectId('6569b5a114c3b0d37a81b3c4'),
#  ObjectId('6569b5a114c3b0d37a81b3c5'),
#  ObjectId('6569b5a114c3b0d37a81b3c6'),
#  ObjectId('6569b5a114c3b0d37a81b3c7'),
#  ObjectId('6569b5a114c3b0d37a81b3c8'),
#  ObjectId('6569b5a114c3b0d37a81b3c9'),
#  ObjectId('6569b5a114c3b0d37a81b3ca'),
#  ObjectId('6569b5a114c3b0d37a81b3cb'),
#  ObjectId('6569b5a114c3b0d37a81b3cc'),
#  ObjectId('6569b5a114c3b0d37a81b3cd'),
#  ObjectId('6569b5a114c3b0d37a81b3ce'),
#  ObjectId('6569b5a114c3b0d37a81b3cf'),
#  ObjectId('6569b5a114c3b0d37a81b3d0'),
#  ObjectId('6569b5a114c3b0d37a81b3d1'),
#  ObjectId('6569b5a114c3b0d37a81b3d2'),
#  ObjectId('6569b5a114c3b0d37a81b3d3'),
#  ObjectId('6569b5a114c3b0d37a81b3d4'),
#  ObjectId('6569b5a114c3b0d37a81b3d5'),
#  ObjectId('6569b5a114c3b0d37a81b3d6'),
#  ObjectId('6569b5a114c3b0d37a81b3d7'),
#  ObjectId('6569b5a114c3b0d37a81b3d8'),
#  ObjectId('6569b5a114c3b0d37a81b3d9'),
#  ObjectId('6569b5a114c3b0d37a81b3da'),
#  ObjectId('6569b5a114c3b0d37a81b3db'),
#  ObjectId('6569b5a114c3b0d37a81b3dc'),
#  ObjectId('6569b5a114c3b0d37a81b3dd'),
#  ObjectId('6569b5a114c3b0d37a81b3de'),
#  ObjectId('6569b5a114c3b0d37a81b3df'),
#  ObjectId('6569b5a114c3b0d37a81b3e0'),
#  ObjectId('6569b5a114c3b0d37a81b3e1'),
#  ObjectId('6569b5a114c3b0d37a81b3e2'),
#  ObjectId('6569b5a114c3b0d37a81b3e3'),
#  ObjectId('6569b5a114c3b0d37a81b3e4'),
#  ObjectId('6569b5a114c3b0d37a81b3e5'),
#  ObjectId('6569b5a114c3b0d37a81b3e6'),
#  ObjectId('6569b5a114c3b0d37a81b3e7'),
#  ObjectId('6569b5a114c3b0d37a81b3e8'),
#  ObjectId('6569b5a114c3b0d37a81b3e9'),
#  ObjectId('6569b5a114c3b0d37a81b3ea'),
#  ObjectId('6569b5a114c3b0d37a81b3eb'),
#  ObjectId('6569b5a114c3b0d37a81b3ec'),
#  ObjectId('6569b5a114c3b0d37a81b3ed'),
#  ObjectId('6569b5a114c3b0d37a81b3ee'),
#  ObjectId('6569b5a114c3b0d37a81b3ef'),
#  ObjectId('6569b5a114c3b0d37a81b3f0'),
#  ObjectId('6569b5a114c3b0d37a81b3f1'),
#  ObjectId('6569b5a114c3b0d37a81b3f2'),
#  ObjectId('6569b5a114c3b0d37a81b3f3'),
#  ObjectId('6569b5a114c3b0d37a81b3f4'),
#  ObjectId('6569b5a114c3b0d37a81b3f5'),
#  ObjectId('6569b5a114c3b0d37a81b3f6'),
#  ObjectId('6569b5a114c3b0d37a81b3f7'),
#  ObjectId('6569b5a114c3b0d37a81b3f8'),
#  ObjectId('6569b5a114c3b0d37a81b3f9'),
#  ObjectId('6569b5a114c3b0d37a81b3fa'),
#  ObjectId('6569b5a114c3b0d37a81b3fb'),
#  ObjectId('6569b5a114c3b0d37a81b3fc'),
#  ObjectId('6569b5a114c3b0d37a81b3fd'),
#  ObjectId('6569b5a114c3b0d37a81b3fe'),
#  ObjectId('6569b5a114c3b0d37a81b3ff'),
#  ObjectId('6569b5a114c3b0d37a81b400'),
#  ObjectId('6569b5a114c3b0d37a81b401'),
#  ObjectId('6569b5a114c3b0d37a81b402'),
#  ObjectId('6569b5a114c3b0d37a81b403'),
#  ObjectId('6569b5a114c3b0d37a81b404'),
#  ObjectId('6569b5a114c3b0d37a81b405'),
#  ObjectId('6569b5a114c3b0d37a81b406'),
#  ObjectId('6569b5a114c3b0d37a81b407'),
#  ObjectId('6569b5a114c3b0d37a81b408'),
#  ObjectId('6569b5a114c3b0d37a81b409'),
#  ObjectId('6569b5a114c3b0d37a81b40a'),
#  ObjectId('6569b5a114c3b0d37a81b40b'),
#  ObjectId('6569b5a114c3b0d37a81b40c'),
#  ObjectId('6569b5a114c3b0d37a81b40d'),
#  ObjectId('6569b5a114c3b0d37a81b40e'),
#  ObjectId('6569b5a114c3b0d37a81b40f'),
#  ObjectId('6569b5a114c3b0d37a81b410'),
#  ObjectId('6569b5a114c3b0d37a81b411'),
#  ObjectId('6569b5a114c3b0d37a81b412'),
#  ObjectId('6569b5a114c3b0d37a81b413'),
#  ObjectId('6569b5a114c3b0d37a81b414'),
#  ObjectId('6569b5a114c3b0d37a81b415'),
#  ObjectId('6569b5a114c3b0d37a81b416'),
#  ObjectId('6569b5a114c3b0d37a81b417'),
#  ObjectId('6569b5a114c3b0d37a81b418'),
#  ObjectId('6569b5a114c3b0d37a81b419'),
#  ObjectId('6569b5a114c3b0d37a81b41a'),
#  ObjectId('6569b5a114c3b0d37a81b41b'),
#  ObjectId('6569b5a114c3b0d37a81b41c'),
#  ObjectId('6569b5a114c3b0d37a81b41d'),
#  ObjectId('6569b5a114c3b0d37a81b41e'),
#  ObjectId('6569b5a114c3b0d37a81b41f'),
#  ObjectId('6569b5a114c3b0d37a81b420'),
#  ObjectId('6569b5a114c3b0d37a81b421'),
#  ObjectId('6569b5a114c3b0d37a81b422'),
#  ObjectId('6569b5a114c3b0d37a81b423'),
#  ObjectId('6569b5a114c3b0d37a81b424'),
#  ObjectId('6569b5a114c3b0d37a81b425'),
#  ObjectId('6569b5a114c3b0d37a81b426'),
#  ObjectId('6569b5a114c3b0d37a81b427'),
#  ObjectId('6569b5a114c3b0d37a81b428'),
#  ObjectId('6569b5a114c3b0d37a81b429'),
#  ObjectId('6569b5a114c3b0d37a81b42a'),
#  ObjectId('6569b5a114c3b0d37a81b42b'),
#  ObjectId('6569b5a114c3b0d37a81b42c'),
#  ObjectId('6569b5a114c3b0d37a81b42d'),
#  ObjectId('6569b5a114c3b0d37a81b42e'),
#  ObjectId('6569b5a114c3b0d37a81b42f'),
#  ObjectId('6569b5a114c3b0d37a81b430'),
#  ObjectId('6569b5a114c3b0d37a81b431'),
#  ObjectId('6569b5a114c3b0d37a81b432'),
#  ObjectId('6569b5a114c3b0d37a81b433'),
#  ObjectId('6569b5a114c3b0d37a81b434'),
#  ObjectId('6569b5a114c3b0d37a81b435'),
#  ObjectId('6569b5a114c3b0d37a81b436'),
#  ObjectId('6569b5a114c3b0d37a81b437'),
#  ObjectId('6569b5a114c3b0d37a81b438'),
#  ObjectId('6569b5a114c3b0d37a81b439'),
#  ObjectId('6569b5a114c3b0d37a81b43a'),
#  ObjectId('6569b5a114c3b0d37a81b43b'),
#  ObjectId('6569b5a114c3b0d37a81b43c'),
#  ObjectId('6569b5a114c3b0d37a81b43d'),
#  ObjectId('6569b5a114c3b0d37a81b43e'),
#  ...]

# %%
#first five messages recorded in the database 
records = database.find_all('messages')
for record in records[:5]:
    pprint.pprint(record)
# Out:
# {'_id': ObjectId('6569b59314c3b0d37a81665a'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': 'aaea2ec8-1461-4705-98c0-fda055acf96e',
#  'reactions': [],
#  'replies': [],
#  'text': 'morning boss',
#  'ts': '1666940798.397899',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('6569b59314c3b0d37a81665b'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': ['U03UUN8M4RX'],
#  'msg_id': '2c87b913-e78f-4f9b-bc3e-c1a524a0fe0a',
#  'reactions': [{'count': 8,
#                 'name': 'raised_hands',
#                 'users': ['U03U1FNPEUX',
#                           'U03UD68RQH3',
#                           'U03UG32J3PC',
#                           'U03UG0SFHGT',
#                           'U03UG1Z21JP',
#                           'U03UFV7HFNF',
#                           'U03U1HAG9TR',
#                           'U03UJH1EQQL']},
#                {'count': 1,
#                 'name': 'raised_hands::skin-tone-4',
#                 'users': ['U03UG4Q7V42']},
#                {'count': 1,
#                 'name': 'raised_hands::skin-tone-3',
#                 'users': ['U03U9EJR362']},
#                {'count': 5,
#                 'name': '100',
#                 'users': ['U03UVHCV6KB',
#                           'U03UJGP0C68',
#                           'U03UUR571A5',
#                           'U03V785NLSU',
#                           'U03UJKJGRAQ']}],
#  'replies': [],
#  'text': '*hot seat announcement! <!here>*\n'
#          '_*good morning all,*_\n'
#          'the long-awaited day/time is here……guess whom we have in...\n'
#          "this is your only chance to ask all the questions you've been "
#          'curious about without getting in '
#          "trouble:rolling_on_the_floor_laughing:…use it wisely and let's make "
#          'the seat very *hot! i repeat very hot like a hito, like a '
#          'bomb*:boom:\n'
#          "we are *more than* happy to announce today's hotseat guest.\n"
#          'we are very proud to host  our very own  <@u03uun8m4rx>',
#  'ts': '1666941319.221839',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('6569b59314c3b0d37a81665c'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': '7a99b469-fba5-48cc-9735-4a2b0986847b',
#  'reactions': [],
#  'replies': [],
#  'text': "you can find the updated list of the hot seater's quake books "
#          '<https://www.notion.so/quake-books-1a622f5c9a1f4a418126fcc4ce05aa01|here>. '
#          'have fun reading.',
#  'ts': '1666948195.284989',
#  'user_id': 'U03UVHCV6KB'}
# {'_id': ObjectId('6569b59314c3b0d37a81665d'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': 'e7171b8a-ba65-4458-b986-21bee780e7bb',
#  'reactions': [],
#  'replies': [],
#  'text': '*community building session reminder!*:timer_clock: *<!here>*\n'
#          '*please note that cbs is on in the next Joannemin*\n'
#          '• *session: my movie life*\n'
#          '• *time*: from 12:00 pm - 12:30 pm utc\n'
#          '• platform: slack\n',
#  'ts': '1666957800.615229',
#  'user_id': 'U03V1AM5TFA'}
# {'_id': ObjectId('6569b59314c3b0d37a81665e'),
#  'channel_id': 'C03T0APHX63',
#  'mentions': [],
#  'msg_id': '4322aa15-fc2a-4e6f-998b-798ccfb860e2',
#  'reactions': [],
#  'replies': [],
#  'text': 'hello',
#  'ts': '1666958458.036999',
#  'user_id': 'U03UG0YHAUT'}
